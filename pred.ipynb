# %%
import numpy as np
import sys
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding, Flatten
from keras.layers import Conv1D, GlobalMaxPooling1D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.utils import np_utils
import utils
from keras.preprocessing.sequence import pad_sequences

# change the file names to the file for which prediction is being done

FREQ_DIST_FILE = r'C:\Users\Ankita\yashchetnani2-freqdist.pkl'
BI_FREQ_DIST_FILE = r'C:\Users\Ankita\yashchetnani2-freqdist-bi.pkl'
TEST_PROCESSED_FILE = r'C:\Users\Ankita\yashchetnani2-processed.csv'
GLOVE_FILE = r'C:\Users\Ankita\gs100d.txt'
dim = 100


def get_glove_vectors(vocab):
    """
    Extracts glove vectors from seed file only for words present in vocab.
    """
    print ('Looking for GLOVE seeds')
    glove_vectors = {}
    found = 0
    with open(GLOVE_FILE,'r',encoding="utf8") as glove_file:
        for i, line in enumerate(glove_file):
            utils.write_status(i + 1, 0)
            tokens = line.strip().split()
            word = tokens[0]
            if vocab.get(word):
                vector = [float(e) for e in tokens[1:]]
                glove_vectors[word] = np.array(vector)
                found += 1
    print ('\n')
    return glove_vectors


def get_feature_vector(tweet):
    """
    Generates a feature vector for each tweet where each word is
    represented by integer index based on rank in vocabulary.
    """
    words = tweet.split()
    feature_vector = []
    for i in range(len(words) - 1):
        word = words[i]
        if vocab.get(word) is not None:
            feature_vector.append(vocab.get(word))
    if len(words) >= 1:
        if vocab.get(words[-1]) is not None:
            feature_vector.append(vocab.get(words[-1]))
    return feature_vector


def process_tweets(csv_file, test_file=True):
    """
    Generates training X, y pairs.
    """
    tweets = []
    labels = []
    print ('Generating feature vectors')
    with open(csv_file, 'r') as csv:
        lines = csv.readlines()
        total = len(lines)
        for i, line in enumerate(lines):
            if test_file:
                tweet_id, tweet = line.split(',')
            else:
                tweet_id, sentiment, tweet = line.split(',')
            feature_vector = get_feature_vector(tweet)
            if test_file:
                tweets.append(feature_vector)
            else:
                tweets.append(feature_vector)
                labels.append(int(sentiment))
            utils.write_status(i + 1, total)
    print ('\n')
    lbl=np.array(labels)
    label=np_utils.to_categorical(lbl,num_classes=7)
    
    return tweets, label


if __name__ == '__main__':
    train = 1
    np.random.seed(1337)
    vocab_size = 90000
    batch_size = 500
    max_length = 40
    filters = 600
    kernel_size = 3
    vocab = utils.top_n_words(FREQ_DIST_FILE, vocab_size, shift=1)
    glove_vectors = get_glove_vectors(vocab)
    
    # Create and embedding matrix
    embedding_matrix = np.random.randn(vocab_size + 1, dim) * 0.01
    # Seed it with GloVe vectors
    for word, i in vocab.items():
        glove_vector = glove_vectors.get(word)
        if glove_vector is not None:
            embedding_matrix[i] = glove_vecto
    #change models folder and name of hdf5 file according to the type being predicted
    model = load_model(r'C:\Users\Ankita\models2\.hdf5')
    print (model.summary())
    test_tweets, _ = process_tweets(TEST_PROCESSED_FILE, test_file=True)
    test_tweets = pad_sequences(test_tweets, maxlen=max_length, padding='post')
    predictions = model.predict(test_tweets, batch_size=128, verbose=1)
    results = zip(map(str, range(len(test_tweets))), np.round(predictions[:, 0]).astype(int))
    #in the line below change models folder accodring to the type of data being predicted
    utils.save_results_to_csv(results, r'C:\Users\Ankita\models2\cnn2.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Looking for GLOVE seeds
# Processing 1193328/0ocessing 30190/0Processing 50983/0Processing 57582/0Processing 84175/0Processing 100769/0Processing 104168/0Processing 113964/0Processing 128960/0Processing 158753/0Processing 175550/0Processing 182349/0Processing 203147/0Processing 230142/0Processing 248137/0Processing 258736/0Processing 262136/0Processing 279133/0Processing 289930/0Processing 291730/0Processing 343324/0Processing 346723/0Processing 357320/0Processing 391314/0Processing 454899/0Processing 493895/0Processing 500494/0Processing 528889/0Processing 535488/0Processing 573082/0Processing 576481/0Processing 594478/0Processing 598077/0Processing 608475/0Processing 631070/0Processing 659066/0Processing 662665/0Processing 682860/0Processing 708056/0Processing 711455/0Processing 749633/0Processing 801837/0Processing 813835/0Processing 889221/0Processing 930412/0Processing 991203/0Processing 1001600/0Processing 1022597/0Processing 1067590/0Processing 1087987/0Processing 1172953/0Processing 1189545/0WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Train on 882 samples, validate on 99 samples
# Epoch 1/8
# 882/882 [==============================] - 21s 24ms/step - loss: 1.4028 - acc: 0.7007 - val_loss: 1.0238 - val_acc: 0.7576
#
# Epoch 00001: loss improved from inf to 1.40276, saving model to C:\Users\Ankita\models\4cnn-01-1.403-0.701-1.024-0.758.hdf5
# Epoch 2/8
# 882/882 [==============================] - 12s 14ms/step - loss: 0.9895 - acc: 0.7868 - val_loss: 0.8485 - val_acc: 0.7576
#
# Epoch 00002: loss improved from 1.40276 to 0.98951, saving model to C:\Users\Ankita\models\4cnn-02-0.990-0.787-0.849-0.758.hdf5
# Epoch 3/8
# 882/882 [==============================] - 13s 15ms/step - loss: 0.8137 - acc: 0.7868 - val_loss: 0.8722 - val_acc: 0.7576
#
# Epoch 00003: loss improved from 0.98951 to 0.81367, saving model to C:\Users\Ankita\models\4cnn-03-0.814-0.787-0.872-0.758.hdf5
# Epoch 4/8
# 882/882 [==============================] - 9s 10ms/step - loss: 0.8219 - acc: 0.7868 - val_loss: 0.7563 - val_acc: 0.7576
#
# Epoch 00004: loss did not improve
# Epoch 5/8
# 882/882 [==============================] - 9s 11ms/step - loss: 0.7707 - acc: 0.7868 - val_loss: 0.7846 - val_acc: 0.7576
#
# Epoch 00005: loss improved from 0.81367 to 0.77070, saving model to C:\Users\Ankita\models\4cnn-05-0.771-0.787-0.785-0.758.hdf5
# Epoch 6/8
# 882/882 [==============================] - 9s 11ms/step - loss: 0.7226 - acc: 0.7868 - val_loss: 0.7864 - val_acc: 0.7576
#
# Epoch 00006: loss improved from 0.77070 to 0.72263, saving model to C:\Users\Ankita\models\4cnn-06-0.723-0.787-0.786-0.758.hdf5
# Epoch 7/8
# 882/882 [==============================] - 9s 10ms/step - loss: 0.7009 - acc: 0.7868 - val_loss: 0.7887 - val_acc: 0.7576
#
# Epoch 00007: loss improved from 0.72263 to 0.70087, saving model to C:\Users\Ankita\models\4cnn-07-0.701-0.787-0.789-0.758.hdf5
# Epoch 8/8
# 882/882 [==============================] - 9s 10ms/step - loss: 0.6739 - acc: 0.7868 - val_loss: 0.7587 - val_acc: 0.7576
#
# Epoch 00008: loss improved from 0.70087 to 0.67388, saving model to C:\Users\Ankita\models\4cnn-08-0.674-0.787-0.759-0.758.hdf5
